# %%
from pathlib import Path
import pandas as pd

# %%
df = pd.read_csv('wjd/solo_info.csv')
# select columns 'performer', 'title', 'tempoclass', 'rhythmfeel', 'key', 'signature', and 'chord_changes'
df = df[['performer', 'title', 'tempoclass', 'rhythmfeel', 'key', 'signature', 'chord_changes']]

# %%
# sort df by title
df = df.sort_values(by='title')
df.to_csv('chord_changes_orig.csv', index=False)
